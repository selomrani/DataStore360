# %%
import pandas as pd

df = pd.read_csv("../../data/raw/store_data.csv")


def fix_customer_names(data):
    customer_id_to_customer_name = (
    data.dropna(subset=['Customer Name'])
    .drop_duplicates(subset=['Customer ID'])
    .set_index('Customer ID')['Customer Name']
    .to_dict())
    data['Customer Name'] = data['Customer Name'].fillna(data['Customer ID'].map(customer_id_to_customer_name))
    return data

fix_customer_names(df)
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0           1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1           2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2           3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3           4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4           5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...       ...             ...         ...         ...             ...
# 10059    1281  CA-2016-160815    9/5/2016    9/6/2016     First Class
# 10060    7699  CA-2017-151799  12/14/2017  12/18/2017  Standard Class
# 10061    8597  CA-2014-111934    5/5/2014    5/7/2014     First Class
# 10062    4962  CA-2014-156587    3/7/2014    3/8/2014     First Class
# 10063    3998  CA-2015-105627    3/8/2015   3/12/2015  Standard Class
#
#       Customer ID      Customer Name      Segment        Country  \
# 0        CG-12520        Claire Gute     Consumer  United States
# 1        CG-12520        Claire Gute     Consumer  United States
# 2        DV-13045    Darrin Van Huff    Corporate  United States
# 3        SO-20335     Sean O'Donnell     Consumer  United States
# 4        SO-20335     Sean O'Donnell     Consumer  United States
# ...           ...                ...          ...            ...
# 10059    TR-21325       TOBY RITTER      Consumer  United States
# 10060    BF-11170        BEN FERRER   Home Office  United States
# 10061    GD-14590  GIULIETTA DORTCH     Corporate  United States
# 10062    AB-10015      Aaron Bergman     Consumer  United States
# 10063    DK-12895       DANA KAYDOS      Consumer  United States
#
#             Product ID  ...          State Postal Code   Region  \
# 0      FUR-BO-10001798  ...       Kentucky     42420.0    South
# 1      FUR-CH-10000454  ...       Kentucky     42420.0    South
# 2      OFF-LA-10000240  ...     California     90036.0     West
# 3      FUR-TA-10000577  ...        Florida     33311.0    South
# 4      OFF-ST-10000760  ...        Florida     33311.0    South
# ...                ...  ...            ...         ...      ...
# 10059  TEC-PH-10003505  ...           Iowa     52402.0  Central
# 10060  OFF-ST-10002790  ...  Massachusetts      1841.0     East
# 10061  OFF-PA-10000474  ...       Virginia     22204.0    South
# 10062  FUR-CH-10004477  ...     Washington     98103.0     West
# 10063  OFF-AR-10002704  ...      Wisconsin     53142.0  Central
#
#               Category Sub-Category  \
# 0            Furniture    Bookcases
# 1            Furniture       Chairs
# 2      Office Supplies       Labels
# 3            Furniture       Tables
# 4      Office Supplies      Storage
# ...                ...          ...
# 10059       Technology       Phones
# 10060  Office Supplies      Storage
# 10061  Office Supplies        Paper
# 10062        Furniture       Chairs
# 10063  Office Supplies          Art
#
#                                             Product Name     Sales  Quantity  \
# 0                      Bush Somerset Collection Bookcase  261.9600       2.0
# 1      Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400       3.0
# 2      Self-Adhesive Address Labels for Typewriters b...   14.6200       2.0
# 3          Bretford CR4500 Series Slim Rectangular Table  957.5775       5.0
# 4                         Eldon Fold 'N Roll Cart System   22.3680       2.0
# ...                                                  ...       ...       ...
# 10059                               Geemarc AmpliPOWER60  278.4000       3.0
# 10060                          Safco Industrial Shelving   73.8500       1.0
# 10061                                  Easy-staple paper   35.4400       1.0
# 10062         Global Push Button Manager's Chair, Indigo   48.7120       1.0
# 10063              Boston 1900 Electric Pencil Sharpener   14.9800       1.0
#
#        Discount    Profit
# 0          0.00   41.9136
# 1          0.00  219.5820
# 2          0.00    6.8714
# 3          0.45 -383.0310
# 4          0.20    2.5164
# ...         ...       ...
# 10059      0.00   80.7360
# 10060      0.00    2.2155
# 10061      0.00   16.6568
# 10062      0.20    5.4801
# 10063      0.00    4.4940
#
# [10064 rows x 21 columns]
