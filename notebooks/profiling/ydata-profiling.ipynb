# %%
import pandas as pd
from data_profiling import ProfileReport

# %% [markdown]
# Generating a profiling report :

# %%
df = pd.read_csv("../../data/raw/store_data.csv")
profile = ProfileReport(df, title="DataStore360 Profiling Report", explorative=True)
profile.to_file("../../reports/datastore360_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
